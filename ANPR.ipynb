# %%
cd "C:\Users\streo\ANPR"
# Out:
# C:\Users\streo\ANPR

# %%
pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python predict.py model="C:\Users\streo\ANPR\license_detector.pt" source=0 show=true
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 2024-06-14 17:28:56.564220: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-14 17:28:58.685344: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Ultralytics YOLOv8.0.3  Python-3.11.5 torch-2.3.0+cpu CPU
# Fusing layers...
# Model summary: 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
#
# 0: 480x640 263.1ms
# 0: 480x640 238.7ms
# 0: 480x640 217.7ms
# 0: 480x640 227.9ms
# ...

# %%
# !python predictCsv.py model="C:\Users\streo\ANPR\license_detector.pt" source=0 show=true
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 2024-06-14 17:38:43.239980: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-14 17:38:45.875185: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Ultralytics YOLOv8.0.3  Python-3.11.5 torch-2.3.0+cpu CPU
# Fusing layers...
# Model summary: 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
#
# 0: 480x640 273.3ms
# 0: 480x640 258.1ms
# 0: 480x640 223.9ms
# 0: 480x640 202.9ms
# ...
